# %%
import secrets
import qrcode
from IPython.display import display

def generate_lotto_numbers():
    numbers = set()
    while len(numbers) < 6:
        number = secrets.randbelow(45) + 1  # 1~45까지의 랜덤 숫자
        numbers.add(number)
    return sorted(numbers)

# 사용자 입력 및 로또 추첨
try:
    count = int(input("로또 세트 개수를 입력하세요 (예: 1~5): "))
    if count < 1:
        print("1 이상의 숫자를 입력하세요.")
    else:
        result_text = "===== 로또 번호 추첨 결과 =====\n"
        for i in range(1, count + 1):
            lotto = generate_lotto_numbers()
            result_text += f"{i}세트: {lotto}\n"
        
        print(result_text)

        # QR코드 생성
        qr = qrcode.make(result_text)
        qr.show()
        display(qr)

except ValueError:
    print("숫자만 입력해주세요.")
# Out:
# ===== 로또 번호 추첨 결과 =====
# 1세트: [6, 8, 9, 28, 30, 43]
# 2세트: [1, 12, 20, 37, 38, 41]
# 3세트: [14, 19, 31, 35, 41, 44]
# 4세트: [10, 13, 19, 40, 43, 44]
# 5세트: [6, 7, 9, 20, 22, 28]

# %%
pip install qrcode pillow
# Out:
# Collecting qrcode
#   Downloading qrcode-8.2-py3-none-any.whl.metadata (17 kB)
# Collecting pillow
#   Downloading pillow-11.3.0-cp313-cp313-win_amd64.whl.metadata (9.2 kB)
# Requirement already satisfied: colorama in c:\workspace\example\python_study\.venv\lib\site-packages (from qrcode) (0.4.6)
# Downloading qrcode-8.2-py3-none-any.whl (45 kB)
# Downloading pillow-11.3.0-cp313-cp313-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 7.0/7.0 MB 58.5 MB/s eta 0:00:00
# Installing collected packages: qrcode, pillow
#
#    ---------------------------------------- 0/2 [qrcode]
#    -------------------- ------------------- 1/2 [pillow]
#    -------------------- ------------------- 1/2 [pillow]
#    -------------------- ------------------- 1/2 [pillow]
#    -------------------- ------------------- 1/2 [pillow]
#    -------------------- ------------------- 1/2 [pillow]
#    -------------------- ------------------- 1/2 [pillow]
#    ---------------------------------------- 2/2 [pillow]
#
# Successfully installed pillow-11.3.0 qrcode-8.2
# Note: you may need to restart the kernel to use updated packages.
